# %% [markdown]
# # Очистка данных

# %% [markdown]
# ## Чтение данных

# %% [markdown]
# Загрузим данные на машину (colab only)

# %%
# from google.colab import drive
# drive.mount('/gdrive')
# !cp -r /gdrive/Othercomputers/"My Zenbook"/xgbse_analytics/lending_data ./lending_data

# %% [markdown]
# Прочитаем данные о одобренных кредитах

# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
accepted = pd.read_csv('./lending_data/accepted.csv', low_memory=False)
accepted.head().transpose()
# Out:
#                                                                                             0
# id                                                                                   68407277  \
# member_id                                                                                 NaN
# loan_amnt                                                                              3600.0
# funded_amnt                                                                            3600.0
# funded_amnt_inv                                                                        3600.0
# term                                                                                36 months
# int_rate                                                                                13.99
# installment                                                                            123.03
# grade                                                                                       C
# sub_grade                                                                                  C4
# emp_title                                                                             leadman
# emp_length                                                                          10+ years
# home_ownership                                                                       MORTGAGE
# annual_inc                                                                            55000.0
# verification_status                                                              Not Verified
# issue_d                                                                              Dec-2015
# loan_status                                                                        Fully Paid
# pymnt_plan                                                                                  n
# url                                         https://lendingclub.com/browse/loanDetail.acti...
# desc                                                                                      NaN
# purpose                                                                    debt_consolidation
# title                                                                      Debt consolidation
# zip_code                                                                                190xx
# addr_state                                                                                 PA
# dti                                                                                      5.91
# delinq_2yrs                                                                               0.0
# earliest_cr_line                                                                     Aug-2003
# fico_range_low                                                                          675.0
# fico_range_high                                                                         679.0
# inq_last_6mths                                                                            1.0
# mths_since_last_delinq                                                                   30.0
# mths_since_last_record                                                                    NaN
# open_acc                                                                                  7.0
# pub_rec                                                                                   0.0
# revol_bal                                                                              2765.0
# revol_util                                                                               29.7
# total_acc                                                                                13.0
# initial_list_status                                                                         w
# out_prncp                                                                                 0.0
# out_prncp_inv                                                                             0.0
# total_pymnt                                                                       4421.723917
# total_pymnt_inv                                                                       4421.72
# total_rec_prncp                                                                        3600.0
# total_rec_int                                                                          821.72
# total_rec_late_fee                                                                        0.0
# recoveries                                                                                0.0
# collection_recovery_fee                                                                   0.0
# last_pymnt_d                                                                         Jan-2019
# last_pymnt_amnt                                                                        122.67
# next_pymnt_d                                                                              NaN
# last_credit_pull_d                                                                   Mar-2019
# last_fico_range_high                                                                    564.0
# last_fico_range_low                                                                     560.0
# collections_12_mths_ex_med                                                                0.0
# mths_since_last_major_derog                                                              30.0
# policy_code                                                                               1.0
# application_type                                                                   Individual
# annual_inc_joint                                                                          NaN
# dti_joint                                                                                 NaN
# verification_status_joint                                                                 NaN
# acc_now_delinq                                                                            0.0
# tot_coll_amt                                                                            722.0
# tot_cur_bal                                                                          144904.0
# open_acc_6m                                                                               2.0
# open_act_il                                                                               2.0
# open_il_12m                                                                               0.0
# open_il_24m                                                                               1.0
# mths_since_rcnt_il                                                                       21.0
# total_bal_il                                                                           4981.0
# il_util                                                                                  36.0
# open_rv_12m                                                                               3.0
# open_rv_24m                                                                               3.0
# max_bal_bc                                                                              722.0
# all_util                                                                                 34.0
# total_rev_hi_lim                                                                       9300.0
# inq_fi                                                                                    3.0
# total_cu_tl                                                                               1.0
# inq_last_12m                                                                              4.0
# acc_open_past_24mths                                                                      4.0
# avg_cur_bal                                                                           20701.0
# bc_open_to_buy                                                                         1506.0
# bc_util                                                                                  37.2
# chargeoff_within_12_mths                                                                  0.0
# delinq_amnt                                                                               0.0
# mo_sin_old_il_acct                                                                      148.0
# mo_sin_old_rev_tl_op                                                                    128.0
# mo_sin_rcnt_rev_tl_op                                                                     3.0
# mo_sin_rcnt_tl                                                                            3.0
# mort_acc                                                                                  1.0
# mths_since_recent_bc                                                                      4.0
# mths_since_recent_bc_dlq                                                                 69.0
# mths_since_recent_inq                                                                     4.0
# mths_since_recent_revol_delinq                                                           69.0
# num_accts_ever_120_pd                                                                     2.0
# num_actv_bc_tl                                                                            2.0
# num_actv_rev_tl                                                                           4.0
# num_bc_sats                                                                               2.0
# num_bc_tl                                                                                 5.0
# num_il_tl                                                                                 3.0
# num_op_rev_tl                                                                             4.0
# num_rev_accts                                                                             9.0
# num_rev_tl_bal_gt_0                                                                       4.0
# num_sats                                                                                  7.0
# num_tl_120dpd_2m                                                                          0.0
# num_tl_30dpd                                                                              0.0
# num_tl_90g_dpd_24m                                                                        0.0
# num_tl_op_past_12m                                                                        3.0
# pct_tl_nvr_dlq                                                                           76.9
# percent_bc_gt_75                                                                          0.0
# pub_rec_bankruptcies                                                                      0.0
# tax_liens                                                                                 0.0
# tot_hi_cred_lim                                                                      178050.0
# total_bal_ex_mort                                                                      7746.0
# total_bc_limit                                                                         2400.0
# total_il_high_credit_limit                                                            13734.0
# revol_bal_joint                                                                           NaN
# sec_app_fico_range_low                                                                    NaN
# sec_app_fico_range_high                                                                   NaN
# sec_app_earliest_cr_line                                                                  NaN
# sec_app_inq_last_6mths                                                                    NaN
# sec_app_mort_acc                                                                          NaN
# sec_app_open_acc                                                                          NaN
# sec_app_revol_util                                                                        NaN
# sec_app_open_act_il                                                                       NaN
# sec_app_num_rev_accts                                                                     NaN
# sec_app_chargeoff_within_12_mths                                                          NaN
# sec_app_collections_12_mths_ex_med                                                        NaN
# sec_app_mths_since_last_major_derog                                                       NaN
# hardship_flag                                                                               N
# hardship_type                                                                             NaN
# hardship_reason                                                                           NaN
# hardship_status                                                                           NaN
# deferral_term                                                                             NaN
# hardship_amount                                                                           NaN
# hardship_start_date                                                                       NaN
# hardship_end_date                                                                         NaN
# payment_plan_start_date                                                                   NaN
# hardship_length                                                                           NaN
# hardship_dpd                                                                              NaN
# hardship_loan_status                                                                      NaN
# orig_projected_additional_accrued_interest                                                NaN
# hardship_payoff_balance_amount                                                            NaN
# hardship_last_payment_amount                                                              NaN
# disbursement_method                                                                      Cash
# debt_settlement_flag                                                                        N
# debt_settlement_flag_date                                                                 NaN
# settlement_status                                                                         NaN
# settlement_date                                                                           NaN
# settlement_amount                                                                         NaN
# settlement_percentage                                                                     NaN
# settlement_term                                                                           NaN
#
#                                                                                             1
# id                                                                                   68355089  \
# member_id                                                                                 NaN
# loan_amnt                                                                             24700.0
# funded_amnt                                                                           24700.0
# funded_amnt_inv                                                                       24700.0
# term                                                                                36 months
# int_rate                                                                                11.99
# installment                                                                            820.28
# grade                                                                                       C
# sub_grade                                                                                  C1
# emp_title                                                                            Engineer
# emp_length                                                                          10+ years
# home_ownership                                                                       MORTGAGE
# annual_inc                                                                            65000.0
# verification_status                                                              Not Verified
# issue_d                                                                              Dec-2015
# loan_status                                                                        Fully Paid
# pymnt_plan                                                                                  n
# url                                         https://lendingclub.com/browse/loanDetail.acti...
# desc                                                                                      NaN
# purpose                                                                        small_business
# title                                                                                Business
# zip_code                                                                                577xx
# addr_state                                                                                 SD
# dti                                                                                     16.06
# delinq_2yrs                                                                               1.0
# earliest_cr_line                                                                     Dec-1999
# fico_range_low                                                                          715.0
# fico_range_high                                                                         719.0
# inq_last_6mths                                                                            4.0
# mths_since_last_delinq                                                                    6.0
# mths_since_last_record                                                                    NaN
# open_acc                                                                                 22.0
# pub_rec                                                                                   0.0
# revol_bal                                                                             21470.0
# revol_util                                                                               19.2
# total_acc                                                                                38.0
# initial_list_status                                                                         w
# out_prncp                                                                                 0.0
# out_prncp_inv                                                                             0.0
# total_pymnt                                                                          25679.66
# total_pymnt_inv                                                                      25679.66
# total_rec_prncp                                                                       24700.0
# total_rec_int                                                                          979.66
# total_rec_late_fee                                                                        0.0
# recoveries                                                                                0.0
# collection_recovery_fee                                                                   0.0
# last_pymnt_d                                                                         Jun-2016
# last_pymnt_amnt                                                                        926.35
# next_pymnt_d                                                                              NaN
# last_credit_pull_d                                                                   Mar-2019
# last_fico_range_high                                                                    699.0
# last_fico_range_low                                                                     695.0
# collections_12_mths_ex_med                                                                0.0
# mths_since_last_major_derog                                                               NaN
# policy_code                                                                               1.0
# application_type                                                                   Individual
# annual_inc_joint                                                                          NaN
# dti_joint                                                                                 NaN
# verification_status_joint                                                                 NaN
# acc_now_delinq                                                                            0.0
# tot_coll_amt                                                                              0.0
# tot_cur_bal                                                                          204396.0
# open_acc_6m                                                                               1.0
# open_act_il                                                                               1.0
# open_il_12m                                                                               0.0
# open_il_24m                                                                               1.0
# mths_since_rcnt_il                                                                       19.0
# total_bal_il                                                                          18005.0
# il_util                                                                                  73.0
# open_rv_12m                                                                               2.0
# open_rv_24m                                                                               3.0
# max_bal_bc                                                                             6472.0
# all_util                                                                                 29.0
# total_rev_hi_lim                                                                     111800.0
# inq_fi                                                                                    0.0
# total_cu_tl                                                                               0.0
# inq_last_12m                                                                              6.0
# acc_open_past_24mths                                                                      4.0
# avg_cur_bal                                                                            9733.0
# bc_open_to_buy                                                                        57830.0
# bc_util                                                                                  27.1
# chargeoff_within_12_mths                                                                  0.0
# delinq_amnt                                                                               0.0
# mo_sin_old_il_acct                                                                      113.0
# mo_sin_old_rev_tl_op                                                                    192.0
# mo_sin_rcnt_rev_tl_op                                                                     2.0
# mo_sin_rcnt_tl                                                                            2.0
# mort_acc                                                                                  4.0
# mths_since_recent_bc                                                                      2.0
# mths_since_recent_bc_dlq                                                                  NaN
# mths_since_recent_inq                                                                     0.0
# mths_since_recent_revol_delinq                                                            6.0
# num_accts_ever_120_pd                                                                     0.0
# num_actv_bc_tl                                                                            5.0
# num_actv_rev_tl                                                                           5.0
# num_bc_sats                                                                              13.0
# num_bc_tl                                                                                17.0
# num_il_tl                                                                                 6.0
# num_op_rev_tl                                                                            20.0
# num_rev_accts                                                                            27.0
# num_rev_tl_bal_gt_0                                                                       5.0
# num_sats                                                                                 22.0
# num_tl_120dpd_2m                                                                          0.0
# num_tl_30dpd                                                                              0.0
# num_tl_90g_dpd_24m                                                                        0.0
# num_tl_op_past_12m                                                                        2.0
# pct_tl_nvr_dlq                                                                           97.4
# percent_bc_gt_75                                                                          7.7
# pub_rec_bankruptcies                                                                      0.0
# tax_liens                                                                                 0.0
# tot_hi_cred_lim                                                                      314017.0
# total_bal_ex_mort                                                                     39475.0
# total_bc_limit                                                                        79300.0
# total_il_high_credit_limit                                                            24667.0
# revol_bal_joint                                                                           NaN
# sec_app_fico_range_low                                                                    NaN
# sec_app_fico_range_high                                                                   NaN
# sec_app_earliest_cr_line                                                                  NaN
# sec_app_inq_last_6mths                                                                    NaN
# sec_app_mort_acc                                                                          NaN
# sec_app_open_acc                                                                          NaN
# sec_app_revol_util                                                                        NaN
# sec_app_open_act_il                                                                       NaN
# sec_app_num_rev_accts                                                                     NaN
# sec_app_chargeoff_within_12_mths                                                          NaN
# sec_app_collections_12_mths_ex_med                                                        NaN
# sec_app_mths_since_last_major_derog                                                       NaN
# hardship_flag                                                                               N
# hardship_type                                                                             NaN
# hardship_reason                                                                           NaN
# hardship_status                                                                           NaN
# deferral_term                                                                             NaN
# hardship_amount                                                                           NaN
# hardship_start_date                                                                       NaN
# hardship_end_date                                                                         NaN
# payment_plan_start_date                                                                   NaN
# hardship_length                                                                           NaN
# hardship_dpd                                                                              NaN
# hardship_loan_status                                                                      NaN
# orig_projected_additional_accrued_interest                                                NaN
# hardship_payoff_balance_amount                                                            NaN
# hardship_last_payment_amount                                                              NaN
# disbursement_method                                                                      Cash
# debt_settlement_flag                                                                        N
# debt_settlement_flag_date                                                                 NaN
# settlement_status                                                                         NaN
# settlement_date                                                                           NaN
# settlement_amount                                                                         NaN
# settlement_percentage                                                                     NaN
# settlement_term                                                                           NaN
#
#                                                                                             2
# id                                                                                   68341763  \
# member_id                                                                                 NaN
# loan_amnt                                                                             20000.0
# funded_amnt                                                                           20000.0
# funded_amnt_inv                                                                       20000.0
# term                                                                                60 months
# int_rate                                                                                10.78
# installment                                                                            432.66
# grade                                                                                       B
# sub_grade                                                                                  B4
# emp_title                                                                        truck driver
# emp_length                                                                          10+ years
# home_ownership                                                                       MORTGAGE
# annual_inc                                                                            63000.0
# verification_status                                                              Not Verified
# issue_d                                                                              Dec-2015
# loan_status                                                                        Fully Paid
# pymnt_plan                                                                                  n
# url                                         https://lendingclub.com/browse/loanDetail.acti...
# desc                                                                                      NaN
# purpose                                                                      home_improvement
# title                                                                                     NaN
# zip_code                                                                                605xx
# addr_state                                                                                 IL
# dti                                                                                     10.78
# delinq_2yrs                                                                               0.0
# earliest_cr_line                                                                     Aug-2000
# fico_range_low                                                                          695.0
# fico_range_high                                                                         699.0
# inq_last_6mths                                                                            0.0
# mths_since_last_delinq                                                                    NaN
# mths_since_last_record                                                                    NaN
# open_acc                                                                                  6.0
# pub_rec                                                                                   0.0
# revol_bal                                                                              7869.0
# revol_util                                                                               56.2
# total_acc                                                                                18.0
# initial_list_status                                                                         w
# out_prncp                                                                                 0.0
# out_prncp_inv                                                                             0.0
# total_pymnt                                                                      22705.924294
# total_pymnt_inv                                                                      22705.92
# total_rec_prncp                                                                       20000.0
# total_rec_int                                                                         2705.92
# total_rec_late_fee                                                                        0.0
# recoveries                                                                                0.0
# collection_recovery_fee                                                                   0.0
# last_pymnt_d                                                                         Jun-2017
# last_pymnt_amnt                                                                       15813.3
# next_pymnt_d                                                                              NaN
# last_credit_pull_d                                                                   Mar-2019
# last_fico_range_high                                                                    704.0
# last_fico_range_low                                                                     700.0
# collections_12_mths_ex_med                                                                0.0
# mths_since_last_major_derog                                                               NaN
# policy_code                                                                               1.0
# application_type                                                                    Joint App
# annual_inc_joint                                                                      71000.0
# dti_joint                                                                               13.85
# verification_status_joint                                                        Not Verified
# acc_now_delinq                                                                            0.0
# tot_coll_amt                                                                              0.0
# tot_cur_bal                                                                          189699.0
# open_acc_6m                                                                               0.0
# open_act_il                                                                               1.0
# open_il_12m                                                                               0.0
# open_il_24m                                                                               4.0
# mths_since_rcnt_il                                                                       19.0
# total_bal_il                                                                          10827.0
# il_util                                                                                  73.0
# open_rv_12m                                                                               0.0
# open_rv_24m                                                                               2.0
# max_bal_bc                                                                             2081.0
# all_util                                                                                 65.0
# total_rev_hi_lim                                                                      14000.0
# inq_fi                                                                                    2.0
# total_cu_tl                                                                               5.0
# inq_last_12m                                                                              1.0
# acc_open_past_24mths                                                                      6.0
# avg_cur_bal                                                                           31617.0
# bc_open_to_buy                                                                         2737.0
# bc_util                                                                                  55.9
# chargeoff_within_12_mths                                                                  0.0
# delinq_amnt                                                                               0.0
# mo_sin_old_il_acct                                                                      125.0
# mo_sin_old_rev_tl_op                                                                    184.0
# mo_sin_rcnt_rev_tl_op                                                                    14.0
# mo_sin_rcnt_tl                                                                           14.0
# mort_acc                                                                                  5.0
# mths_since_recent_bc                                                                    101.0
# mths_since_recent_bc_dlq                                                                  NaN
# mths_since_recent_inq                                                                    10.0
# mths_since_recent_revol_delinq                                                            NaN
# num_accts_ever_120_pd                                                                     0.0
# num_actv_bc_tl                                                                            2.0
# num_actv_rev_tl                                                                           3.0
# num_bc_sats                                                                               2.0
# num_bc_tl                                                                                 4.0
# num_il_tl                                                                                 6.0
# num_op_rev_tl                                                                             4.0
# num_rev_accts                                                                             7.0
# num_rev_tl_bal_gt_0                                                                       3.0
# num_sats                                                                                  6.0
# num_tl_120dpd_2m                                                                          0.0
# num_tl_30dpd                                                                              0.0
# num_tl_90g_dpd_24m                                                                        0.0
# num_tl_op_past_12m                                                                        0.0
# pct_tl_nvr_dlq                                                                          100.0
# percent_bc_gt_75                                                                         50.0
# pub_rec_bankruptcies                                                                      0.0
# tax_liens                                                                                 0.0
# tot_hi_cred_lim                                                                      218418.0
# total_bal_ex_mort                                                                     18696.0
# total_bc_limit                                                                         6200.0
# total_il_high_credit_limit                                                            14877.0
# revol_bal_joint                                                                           NaN
# sec_app_fico_range_low                                                                    NaN
# sec_app_fico_range_high                                                                   NaN
# sec_app_earliest_cr_line                                                                  NaN
# sec_app_inq_last_6mths                                                                    NaN
# sec_app_mort_acc                                                                          NaN
# sec_app_open_acc                                                                          NaN
# sec_app_revol_util                                                                        NaN
# sec_app_open_act_il                                                                       NaN
# sec_app_num_rev_accts                                                                     NaN
# sec_app_chargeoff_within_12_mths                                                          NaN
# sec_app_collections_12_mths_ex_med                                                        NaN
# sec_app_mths_since_last_major_derog                                                       NaN
# hardship_flag                                                                               N
# hardship_type                                                                             NaN
# hardship_reason                                                                           NaN
# hardship_status                                                                           NaN
# deferral_term                                                                             NaN
# hardship_amount                                                                           NaN
# hardship_start_date                                                                       NaN
# hardship_end_date                                                                         NaN
# payment_plan_start_date                                                                   NaN
# hardship_length                                                                           NaN
# hardship_dpd                                                                              NaN
# hardship_loan_status                                                                      NaN
# orig_projected_additional_accrued_interest                                                NaN
# hardship_payoff_balance_amount                                                            NaN
# hardship_last_payment_amount                                                              NaN
# disbursement_method                                                                      Cash
# debt_settlement_flag                                                                        N
# debt_settlement_flag_date                                                                 NaN
# settlement_status                                                                         NaN
# settlement_date                                                                           NaN
# settlement_amount                                                                         NaN
# settlement_percentage                                                                     NaN
# settlement_term                                                                           NaN
#
#                                                                                             3
# id                                                                                   66310712  \
# member_id                                                                                 NaN
# loan_amnt                                                                             35000.0
# funded_amnt                                                                           35000.0
# funded_amnt_inv                                                                       35000.0
# term                                                                                60 months
# int_rate                                                                                14.85
# installment                                                                             829.9
# grade                                                                                       C
# sub_grade                                                                                  C5
# emp_title                                                         Information Systems Officer
# emp_length                                                                          10+ years
# home_ownership                                                                       MORTGAGE
# annual_inc                                                                           110000.0
# verification_status                                                           Source Verified
# issue_d                                                                              Dec-2015
# loan_status                                                                           Current
# pymnt_plan                                                                                  n
# url                                         https://lendingclub.com/browse/loanDetail.acti...
# desc                                                                                      NaN
# purpose                                                                    debt_consolidation
# title                                                                      Debt consolidation
# zip_code                                                                                076xx
# addr_state                                                                                 NJ
# dti                                                                                     17.06
# delinq_2yrs                                                                               0.0
# earliest_cr_line                                                                     Sep-2008
# fico_range_low                                                                          785.0
# fico_range_high                                                                         789.0
# inq_last_6mths                                                                            0.0
# mths_since_last_delinq                                                                    NaN
# mths_since_last_record                                                                    NaN
# open_acc                                                                                 13.0
# pub_rec                                                                                   0.0
# revol_bal                                                                              7802.0
# revol_util                                                                               11.6
# total_acc                                                                                17.0
# ...
# hardship_length                                                                           NaN
# hardship_dpd                                                                              NaN
# hardship_loan_status                                                                      NaN
# orig_projected_additional_accrued_interest                                                NaN
# hardship_payoff_balance_amount                                                            NaN
# hardship_last_payment_amount                                                              NaN
# disbursement_method                                                                      Cash
# debt_settlement_flag                                                                        N
# debt_settlement_flag_date                                                                 NaN
# settlement_status                                                                         NaN
# settlement_date                                                                           NaN
# settlement_amount                                                                         NaN
# settlement_percentage                                                                     NaN
# settlement_term                                                                           NaN
#
#                                                                                             4
# id                                                                                   68476807
# member_id                                                                                 NaN
# loan_amnt                                                                             10400.0
# funded_amnt                                                                           10400.0
# funded_amnt_inv                                                                       10400.0
# term                                                                                60 months
# int_rate                                                                                22.45
# installment                                                                            289.91
# grade                                                                                       F
# sub_grade                                                                                  F1
# emp_title                                                                 Contract Specialist
# emp_length                                                                            3 years
# home_ownership                                                                       MORTGAGE
# annual_inc                                                                           104433.0
# verification_status                                                           Source Verified
# issue_d                                                                              Dec-2015
# loan_status                                                                        Fully Paid
# pymnt_plan                                                                                  n
# url                                         https://lendingclub.com/browse/loanDetail.acti...
# desc                                                                                      NaN
# purpose                                                                        major_purchase
# title                                                                          Major purchase
# zip_code                                                                                174xx
# addr_state                                                                                 PA
# dti                                                                                     25.37
# delinq_2yrs                                                                               1.0
# earliest_cr_line                                                                     Jun-1998
# fico_range_low                                                                          695.0
# fico_range_high                                                                         699.0
# inq_last_6mths                                                                            3.0
# mths_since_last_delinq                                                                   12.0
# mths_since_last_record                                                                    NaN
# open_acc                                                                                 12.0
# pub_rec                                                                                   0.0
# revol_bal                                                                             21929.0
# revol_util                                                                               64.5
# total_acc                                                                                35.0
# initial_list_status                                                                         w
# out_prncp                                                                                 0.0
# out_prncp_inv                                                                             0.0
# total_pymnt                                                                           11740.5
# total_pymnt_inv                                                                       11740.5
# total_rec_prncp                                                                       10400.0
# total_rec_int                                                                          1340.5
# total_rec_late_fee                                                                        0.0
# recoveries                                                                                0.0
# collection_recovery_fee                                                                   0.0
# last_pymnt_d                                                                         Jul-2016
# last_pymnt_amnt                                                                      10128.96
# next_pymnt_d                                                                              NaN
# last_credit_pull_d                                                                   Mar-2018
# last_fico_range_high                                                                    704.0
# last_fico_range_low                                                                     700.0
# collections_12_mths_ex_med                                                                0.0
# mths_since_last_major_derog                                                               NaN
# policy_code                                                                               1.0
# application_type                                                                   Individual
# annual_inc_joint                                                                          NaN
# dti_joint                                                                                 NaN
# verification_status_joint                                                                 NaN
# acc_now_delinq                                                                            0.0
# tot_coll_amt                                                                              0.0
# tot_cur_bal                                                                          331730.0
# open_acc_6m                                                                               1.0
# open_act_il                                                                               3.0
# open_il_12m                                                                               0.0
# open_il_24m                                                                               3.0
# mths_since_rcnt_il                                                                       14.0
# total_bal_il                                                                          73839.0
# il_util                                                                                  84.0
# open_rv_12m                                                                               4.0
# open_rv_24m                                                                               7.0
# max_bal_bc                                                                             9702.0
# all_util                                                                                 78.0
# total_rev_hi_lim                                                                      34000.0
# inq_fi                                                                                    2.0
# total_cu_tl                                                                               1.0
# inq_last_12m                                                                              3.0
# acc_open_past_24mths                                                                     10.0
# avg_cur_bal                                                                           27644.0
# bc_open_to_buy                                                                         4567.0
# bc_util                                                                                  77.5
# chargeoff_within_12_mths                                                                  0.0
# delinq_amnt                                                                               0.0
# mo_sin_old_il_acct                                                                      128.0
# mo_sin_old_rev_tl_op                                                                    210.0
# mo_sin_rcnt_rev_tl_op                                                                     4.0
# mo_sin_rcnt_tl                                                                            4.0
# mort_acc                                                                                  6.0
# mths_since_recent_bc                                                                      4.0
# mths_since_recent_bc_dlq                                                                 12.0
# mths_since_recent_inq                                                                     1.0
# mths_since_recent_revol_delinq                                                           12.0
# num_accts_ever_120_pd                                                                     0.0
# num_actv_bc_tl                                                                            4.0
# num_actv_rev_tl                                                                           6.0
# num_bc_sats                                                                               5.0
# num_bc_tl                                                                                 9.0
# num_il_tl                                                                                10.0
# num_op_rev_tl                                                                             7.0
# num_rev_accts                                                                            19.0
# num_rev_tl_bal_gt_0                                                                       6.0
# num_sats                                                                                 12.0
# num_tl_120dpd_2m                                                                          0.0
# num_tl_30dpd                                                                              0.0
# num_tl_90g_dpd_24m                                                                        0.0
# num_tl_op_past_12m                                                                        4.0
# pct_tl_nvr_dlq                                                                           96.6
# percent_bc_gt_75                                                                         60.0
# pub_rec_bankruptcies                                                                      0.0
# tax_liens                                                                                 0.0
# tot_hi_cred_lim                                                                      439570.0
# total_bal_ex_mort                                                                     95768.0
# total_bc_limit                                                                        20300.0
# total_il_high_credit_limit                                                            88097.0
# revol_bal_joint                                                                           NaN
# sec_app_fico_range_low                                                                    NaN
# sec_app_fico_range_high                                                                   NaN
# sec_app_earliest_cr_line                                                                  NaN
# sec_app_inq_last_6mths                                                                    NaN
# sec_app_mort_acc                                                                          NaN
# sec_app_open_acc                                                                          NaN
# sec_app_revol_util                                                                        NaN
# sec_app_open_act_il                                                                       NaN
# sec_app_num_rev_accts                                                                     NaN
# sec_app_chargeoff_within_12_mths                                                          NaN
# sec_app_collections_12_mths_ex_med                                                        NaN
# sec_app_mths_since_last_major_derog                                                       NaN
# hardship_flag                                                                               N
# hardship_type                                                                             NaN
# hardship_reason                                                                           NaN
# hardship_status                                                                           NaN
# deferral_term                                                                             NaN
# hardship_amount                                                                           NaN
# hardship_start_date                                                                       NaN
# hardship_end_date                                                                         NaN
# payment_plan_start_date                                                                   NaN
# hardship_length                                                                           NaN
# hardship_dpd                                                                              NaN
# hardship_loan_status                                                                      NaN
# orig_projected_additional_accrued_interest                                                NaN
# hardship_payoff_balance_amount                                                            NaN
# hardship_last_payment_amount                                                              NaN
# disbursement_method                                                                      Cash
# debt_settlement_flag                                                                        N
# debt_settlement_flag_date                                                                 NaN
# settlement_status                                                                         NaN
# settlement_date                                                                           NaN
# settlement_amount                                                                         NaN
# settlement_percentage                                                                     NaN
# settlement_term                                                                           NaN

# %%
origin_cols = set(accepted.columns)

# %%
accepted.shape
# Out:
# (2260701, 151)

# %% [markdown]
# ## Обработаем колонки

# %% [markdown]
# ### Удалим колонки с уникальными идентификаторами

# %% [markdown]
# - `id` - уникальный идентификатор кредита, для каждого платежа новый.
# - `member_id` - уникальный идентификатор кредитора.
# - `url` - Уникальная ссылка на страницу займа.

# %%
unique_id_cols = [
    'id',
    'member_id',
    'url',
]
accepted.drop(columns=unique_id_cols, inplace=True)

# %% [markdown]
# ### Выбросим все колонки, дублирующие данные

# %% [markdown]
# - `grade` - Отражен в `sub_grade`
# - `int_rate` - Отражен в `sub_grade`
# - `zip_code` - Зашифрован до первых 3 цифр, отражает то же самое, что и `addr_state`, но менее интерпретируем.

# %%
redundand_cols = [
    'grade',
    'int_rate',
    'zip_code',
]
accepted.drop(columns=redundand_cols, inplace=True)

# %% [markdown]
# ### Выбросим колонки, которые сложно обрабатывать

# %% [markdown]
# - `desc` - текстовое описание цели кредита.
# - `title` - Заголовок цели кредита. Частично отражен в `purpose`.
# - `emp_title` - название должности.

# %%
accepted.drop(columns=['desc', 'title', 'emp_title'], inplace=True)

# %% [markdown]
# ### Переведем колонки с датами в тип datetime

# %%
accepted['issue_d'] = pd.to_datetime(accepted['issue_d'], format='%b-%Y')

accepted['earliest_cr_line'] = pd.to_datetime(accepted['earliest_cr_line'],
                                              format='%b-%Y')
accepted['last_credit_pull_d'] = pd.to_datetime(accepted['last_credit_pull_d'],
                                                format='%b-%Y')

accepted['last_pymnt_d'] = pd.to_datetime(accepted['last_pymnt_d'],
                                          format='%b-%Y')

# %% [markdown]
# ### Удалим все колонки, приводящие к утечке целевой переменной

# %% [markdown]
# - `funded_amnt` - Отражает информацию о выплаченной сумме у завершенных кредитов.
# - `funded_amnt_inv` - Отражает информацию о выплаченной сумме у завершенных кредитов, для части от инвесторов.
# - `out_prncp` - Отражает информацию о оставшейся к выплате суммы.
# - `out_prncp_inv`- Отражает информацию о оставшейся к выплате суммы, для части от инвесторов.
# - `total_pymnt` - Обьем уже полученных платежей.
# - `total_pymnt_inv` - Обьем уже полученных платежей, для части от инвесторов.
# - `total_rec_prncp` - Сумма уже выплаченного основного долга
# - `total_rec_int` - Обьем выплаченных процентов по кредиту.
# - `total_rec_late_fee` - Обьем пени за просрочку по кредиту.
# - `recoveries` - Обьем возвращенных средств после дефолта, > 0 означает что дефолт произошел.
# - `collection_recovery_fee` - Обьем возвращенных средств после списания долга. Не равно нулю только в случае, если дефолт по долгу произошел
# - `last_pymnt_d` -  Месяц последнего платежа(Пока не удаляем, необходим для целевой переменной)
# - `last_pymnt_amnt` - Сумма выплат на момент последнего платежа.
# - `debt_settlement_flag` - Флаг, что должник работает с коллекторской компанией
# - `debt_settlement_flag_date` - Дата установки флага `debt_settlement_flag`
# - `settlement_status` - Статус дефолтного плана выплат.
# - `settlement_date` - Дата заключения дефолтного плана выплат.
# - `settlement_amount` - Сумма дефолтного плана выплат.
# - `settlement_percentage` - Сумма дефолтного плана как процент от выданных средств.
# - `settlement_term` - Срок соглашения дефолтных выплат
# - `pymnt_plan` - был ли заключен новый план выплат(заключается после дефолта)
# - `revol_bal` - оборотный остаток по кредиту.
# - `revol_util` - утилизация оборотного остатка.
# - `hardship_flag` - Обращался ли клиент за перерасчетом долга.
# - `hardship_type` - Тип перерасчета
# - `hardship_reason` - Причина перерасчета
# - `hardship_status` - Статус перерасчета
# - `deferral_term` - Количество месяцев уменьшенных платежей
# - `hardship_amount` - Сумма выплат
# - `hardship_start_date` - Дата старта по перерасчету
# - `hardship_end_date` - Окончание периода перерасчета
# - `payment_plan_start_date` - Дата старта плана выплат
# - `hardship_length` - Период перерасчета
# - `hardship_dpd` - Остаток периода перерасчета
# - `hardship_loan_status` - Статус кредита на момент перерасчета
# - `orig_projected_additional_accrued_interest` - Процент, полученный с плана перерасчета
# - `hardship_payoff_balance_amount` - Сумма выплат на начало плана перерасчета
# - `hardship_last_payment_amount` - Сумма выплат на конец плана перерасчета
# - `last_fico_range_high` - наивысший кредитный рейтинг на время последнего запроса
# - `last_fico_range_low` - наихудший кредитный рейтинг на время последнего запроса

# %%
leak_cols = [
    'funded_amnt',
    'funded_amnt_inv',
    'out_prncp',
    'out_prncp_inv',
    'total_pymnt',
    'total_pymnt_inv',
    'total_rec_prncp',
    'total_rec_int',
    'total_rec_late_fee',
    'recoveries',
    'collection_recovery_fee',
    # 'last_pymnt_d', # Leaks
    'last_pymnt_amnt',
    'debt_settlement_flag',
    'debt_settlement_flag_date',
    'settlement_status',
    'settlement_date',
    'settlement_amount',
    'settlement_percentage',
    'settlement_term',
    'pymnt_plan',
    'revol_bal',
    'revol_util',
    'hardship_flag',
    'hardship_type',
    'hardship_reason',
    'hardship_status',
    'deferral_term',
    'hardship_amount',
    'hardship_start_date',
    'hardship_end_date',
    'payment_plan_start_date',
    'hardship_length',
    'hardship_dpd',
    'hardship_loan_status',
    'orig_projected_additional_accrued_interest',
    'hardship_payoff_balance_amount',
    'hardship_last_payment_amount',
    'last_fico_range_high',
    'last_fico_range_low'
]

accepted.drop(columns=leak_cols, inplace=True)
accepted.head().transpose()
# Out:
#                                                        0                    1
# loan_amnt                                         3600.0              24700.0  \
# term                                           36 months            36 months
# installment                                       123.03               820.28
# sub_grade                                             C4                   C1
# emp_length                                     10+ years            10+ years
# home_ownership                                  MORTGAGE             MORTGAGE
# annual_inc                                       55000.0              65000.0
# verification_status                         Not Verified         Not Verified
# issue_d                              2015-12-01 00:00:00  2015-12-01 00:00:00
# loan_status                                   Fully Paid           Fully Paid
# purpose                               debt_consolidation       small_business
# addr_state                                            PA                   SD
# dti                                                 5.91                16.06
# delinq_2yrs                                          0.0                  1.0
# earliest_cr_line                     2003-08-01 00:00:00  1999-12-01 00:00:00
# fico_range_low                                     675.0                715.0
# fico_range_high                                    679.0                719.0
# inq_last_6mths                                       1.0                  4.0
# mths_since_last_delinq                              30.0                  6.0
# mths_since_last_record                               NaN                  NaN
# open_acc                                             7.0                 22.0
# pub_rec                                              0.0                  0.0
# total_acc                                           13.0                 38.0
# initial_list_status                                    w                    w
# last_pymnt_d                         2019-01-01 00:00:00  2016-06-01 00:00:00
# next_pymnt_d                                         NaN                  NaN
# last_credit_pull_d                   2019-03-01 00:00:00  2019-03-01 00:00:00
# collections_12_mths_ex_med                           0.0                  0.0
# mths_since_last_major_derog                         30.0                  NaN
# policy_code                                          1.0                  1.0
# application_type                              Individual           Individual
# annual_inc_joint                                     NaN                  NaN
# dti_joint                                            NaN                  NaN
# verification_status_joint                            NaN                  NaN
# acc_now_delinq                                       0.0                  0.0
# tot_coll_amt                                       722.0                  0.0
# tot_cur_bal                                     144904.0             204396.0
# open_acc_6m                                          2.0                  1.0
# open_act_il                                          2.0                  1.0
# open_il_12m                                          0.0                  0.0
# open_il_24m                                          1.0                  1.0
# mths_since_rcnt_il                                  21.0                 19.0
# total_bal_il                                      4981.0              18005.0
# il_util                                             36.0                 73.0
# open_rv_12m                                          3.0                  2.0
# open_rv_24m                                          3.0                  3.0
# max_bal_bc                                         722.0               6472.0
# all_util                                            34.0                 29.0
# total_rev_hi_lim                                  9300.0             111800.0
# inq_fi                                               3.0                  0.0
# total_cu_tl                                          1.0                  0.0
# inq_last_12m                                         4.0                  6.0
# acc_open_past_24mths                                 4.0                  4.0
# avg_cur_bal                                      20701.0               9733.0
# bc_open_to_buy                                    1506.0              57830.0
# bc_util                                             37.2                 27.1
# chargeoff_within_12_mths                             0.0                  0.0
# delinq_amnt                                          0.0                  0.0
# mo_sin_old_il_acct                                 148.0                113.0
# mo_sin_old_rev_tl_op                               128.0                192.0
# mo_sin_rcnt_rev_tl_op                                3.0                  2.0
# mo_sin_rcnt_tl                                       3.0                  2.0
# mort_acc                                             1.0                  4.0
# mths_since_recent_bc                                 4.0                  2.0
# mths_since_recent_bc_dlq                            69.0                  NaN
# mths_since_recent_inq                                4.0                  0.0
# mths_since_recent_revol_delinq                      69.0                  6.0
# num_accts_ever_120_pd                                2.0                  0.0
# num_actv_bc_tl                                       2.0                  5.0
# num_actv_rev_tl                                      4.0                  5.0
# num_bc_sats                                          2.0                 13.0
# num_bc_tl                                            5.0                 17.0
# num_il_tl                                            3.0                  6.0
# num_op_rev_tl                                        4.0                 20.0
# num_rev_accts                                        9.0                 27.0
# num_rev_tl_bal_gt_0                                  4.0                  5.0
# num_sats                                             7.0                 22.0
# num_tl_120dpd_2m                                     0.0                  0.0
# num_tl_30dpd                                         0.0                  0.0
# num_tl_90g_dpd_24m                                   0.0                  0.0
# num_tl_op_past_12m                                   3.0                  2.0
# pct_tl_nvr_dlq                                      76.9                 97.4
# percent_bc_gt_75                                     0.0                  7.7
# pub_rec_bankruptcies                                 0.0                  0.0
# tax_liens                                            0.0                  0.0
# tot_hi_cred_lim                                 178050.0             314017.0
# total_bal_ex_mort                                 7746.0              39475.0
# total_bc_limit                                    2400.0              79300.0
# total_il_high_credit_limit                       13734.0              24667.0
# revol_bal_joint                                      NaN                  NaN
# sec_app_fico_range_low                               NaN                  NaN
# sec_app_fico_range_high                              NaN                  NaN
# sec_app_earliest_cr_line                             NaN                  NaN
# sec_app_inq_last_6mths                               NaN                  NaN
# sec_app_mort_acc                                     NaN                  NaN
# sec_app_open_acc                                     NaN                  NaN
# sec_app_revol_util                                   NaN                  NaN
# sec_app_open_act_il                                  NaN                  NaN
# sec_app_num_rev_accts                                NaN                  NaN
# sec_app_chargeoff_within_12_mths                     NaN                  NaN
# sec_app_collections_12_mths_ex_med                   NaN                  NaN
# sec_app_mths_since_last_major_derog                  NaN                  NaN
# disbursement_method                                 Cash                 Cash
#
#                                                        2                    3
# loan_amnt                                        20000.0              35000.0  \
# term                                           60 months            60 months
# installment                                       432.66                829.9
# sub_grade                                             B4                   C5
# emp_length                                     10+ years            10+ years
# home_ownership                                  MORTGAGE             MORTGAGE
# annual_inc                                       63000.0             110000.0
# verification_status                         Not Verified      Source Verified
# issue_d                              2015-12-01 00:00:00  2015-12-01 00:00:00
# loan_status                                   Fully Paid              Current
# purpose                                 home_improvement   debt_consolidation
# addr_state                                            IL                   NJ
# dti                                                10.78                17.06
# delinq_2yrs                                          0.0                  0.0
# earliest_cr_line                     2000-08-01 00:00:00  2008-09-01 00:00:00
# fico_range_low                                     695.0                785.0
# fico_range_high                                    699.0                789.0
# inq_last_6mths                                       0.0                  0.0
# mths_since_last_delinq                               NaN                  NaN
# mths_since_last_record                               NaN                  NaN
# open_acc                                             6.0                 13.0
# pub_rec                                              0.0                  0.0
# total_acc                                           18.0                 17.0
# initial_list_status                                    w                    w
# last_pymnt_d                         2017-06-01 00:00:00  2019-02-01 00:00:00
# next_pymnt_d                                         NaN             Apr-2019
# last_credit_pull_d                   2019-03-01 00:00:00  2019-03-01 00:00:00
# collections_12_mths_ex_med                           0.0                  0.0
# mths_since_last_major_derog                          NaN                  NaN
# policy_code                                          1.0                  1.0
# application_type                               Joint App           Individual
# annual_inc_joint                                 71000.0                  NaN
# dti_joint                                          13.85                  NaN
# verification_status_joint                   Not Verified                  NaN
# acc_now_delinq                                       0.0                  0.0
# tot_coll_amt                                         0.0                  0.0
# tot_cur_bal                                     189699.0             301500.0
# open_acc_6m                                          0.0                  1.0
# open_act_il                                          1.0                  1.0
# open_il_12m                                          0.0                  0.0
# open_il_24m                                          4.0                  1.0
# mths_since_rcnt_il                                  19.0                 23.0
# total_bal_il                                     10827.0              12609.0
# il_util                                             73.0                 70.0
# open_rv_12m                                          0.0                  1.0
# open_rv_24m                                          2.0                  1.0
# max_bal_bc                                        2081.0               6987.0
# all_util                                            65.0                 45.0
# total_rev_hi_lim                                 14000.0              67300.0
# inq_fi                                               2.0                  0.0
# total_cu_tl                                          5.0                  1.0
# inq_last_12m                                         1.0                  0.0
# acc_open_past_24mths                                 6.0                  2.0
# avg_cur_bal                                      31617.0              23192.0
# bc_open_to_buy                                    2737.0              54962.0
# bc_util                                             55.9                 12.1
# chargeoff_within_12_mths                             0.0                  0.0
# delinq_amnt                                          0.0                  0.0
# mo_sin_old_il_acct                                 125.0                 36.0
# mo_sin_old_rev_tl_op                               184.0                 87.0
# mo_sin_rcnt_rev_tl_op                               14.0                  2.0
# mo_sin_rcnt_tl                                      14.0                  2.0
# mort_acc                                             5.0                  1.0
# mths_since_recent_bc                               101.0                  2.0
# mths_since_recent_bc_dlq                             NaN                  NaN
# mths_since_recent_inq                               10.0                  NaN
# mths_since_recent_revol_delinq                       NaN                  NaN
# num_accts_ever_120_pd                                0.0                  0.0
# num_actv_bc_tl                                       2.0                  4.0
# num_actv_rev_tl                                      3.0                  5.0
# num_bc_sats                                          2.0                  8.0
# num_bc_tl                                            4.0                 10.0
# num_il_tl                                            6.0                  2.0
# num_op_rev_tl                                        4.0                 10.0
# num_rev_accts                                        7.0                 13.0
# num_rev_tl_bal_gt_0                                  3.0                  5.0
# num_sats                                             6.0                 13.0
# num_tl_120dpd_2m                                     0.0                  0.0
# num_tl_30dpd                                         0.0                  0.0
# num_tl_90g_dpd_24m                                   0.0                  0.0
# num_tl_op_past_12m                                   0.0                  1.0
# pct_tl_nvr_dlq                                     100.0                100.0
# percent_bc_gt_75                                    50.0                  0.0
# pub_rec_bankruptcies                                 0.0                  0.0
# tax_liens                                            0.0                  0.0
# tot_hi_cred_lim                                 218418.0             381215.0
# total_bal_ex_mort                                18696.0              52226.0
# total_bc_limit                                    6200.0              62500.0
# total_il_high_credit_limit                       14877.0              18000.0
# revol_bal_joint                                      NaN                  NaN
# sec_app_fico_range_low                               NaN                  NaN
# sec_app_fico_range_high                              NaN                  NaN
# sec_app_earliest_cr_line                             NaN                  NaN
# sec_app_inq_last_6mths                               NaN                  NaN
# sec_app_mort_acc                                     NaN                  NaN
# sec_app_open_acc                                     NaN                  NaN
# sec_app_revol_util                                   NaN                  NaN
# sec_app_open_act_il                                  NaN                  NaN
# sec_app_num_rev_accts                                NaN                  NaN
# sec_app_chargeoff_within_12_mths                     NaN                  NaN
# sec_app_collections_12_mths_ex_med                   NaN                  NaN
# sec_app_mths_since_last_major_derog                  NaN                  NaN
# disbursement_method                                 Cash                 Cash
#
#                                                        4
# loan_amnt                                        10400.0
# term                                           60 months
# installment                                       289.91
# sub_grade                                             F1
# emp_length                                       3 years
# home_ownership                                  MORTGAGE
# annual_inc                                      104433.0
# verification_status                      Source Verified
# issue_d                              2015-12-01 00:00:00
# loan_status                                   Fully Paid
# purpose                                   major_purchase
# addr_state                                            PA
# dti                                                25.37
# delinq_2yrs                                          1.0
# earliest_cr_line                     1998-06-01 00:00:00
# fico_range_low                                     695.0
# fico_range_high                                    699.0
# inq_last_6mths                                       3.0
# mths_since_last_delinq                              12.0
# mths_since_last_record                               NaN
# open_acc                                            12.0
# pub_rec                                              0.0
# total_acc                                           35.0
# initial_list_status                                    w
# last_pymnt_d                         2016-07-01 00:00:00
# next_pymnt_d                                         NaN
# last_credit_pull_d                   2018-03-01 00:00:00
# collections_12_mths_ex_med                           0.0
# mths_since_last_major_derog                          NaN
# policy_code                                          1.0
# application_type                              Individual
# annual_inc_joint                                     NaN
# dti_joint                                            NaN
# verification_status_joint                            NaN
# acc_now_delinq                                       0.0
# tot_coll_amt                                         0.0
# tot_cur_bal                                     331730.0
# open_acc_6m                                          1.0
# open_act_il                                          3.0
# open_il_12m                                          0.0
# open_il_24m                                          3.0
# mths_since_rcnt_il                                  14.0
# total_bal_il                                     73839.0
# il_util                                             84.0
# open_rv_12m                                          4.0
# open_rv_24m                                          7.0
# max_bal_bc                                        9702.0
# all_util                                            78.0
# total_rev_hi_lim                                 34000.0
# inq_fi                                               2.0
# total_cu_tl                                          1.0
# inq_last_12m                                         3.0
# acc_open_past_24mths                                10.0
# avg_cur_bal                                      27644.0
# bc_open_to_buy                                    4567.0
# bc_util                                             77.5
# chargeoff_within_12_mths                             0.0
# delinq_amnt                                          0.0
# mo_sin_old_il_acct                                 128.0
# mo_sin_old_rev_tl_op                               210.0
# mo_sin_rcnt_rev_tl_op                                4.0
# mo_sin_rcnt_tl                                       4.0
# mort_acc                                             6.0
# mths_since_recent_bc                                 4.0
# mths_since_recent_bc_dlq                            12.0
# mths_since_recent_inq                                1.0
# mths_since_recent_revol_delinq                      12.0
# num_accts_ever_120_pd                                0.0
# num_actv_bc_tl                                       4.0
# num_actv_rev_tl                                      6.0
# num_bc_sats                                          5.0
# num_bc_tl                                            9.0
# num_il_tl                                           10.0
# num_op_rev_tl                                        7.0
# num_rev_accts                                       19.0
# num_rev_tl_bal_gt_0                                  6.0
# num_sats                                            12.0
# num_tl_120dpd_2m                                     0.0
# num_tl_30dpd                                         0.0
# num_tl_90g_dpd_24m                                   0.0
# num_tl_op_past_12m                                   4.0
# pct_tl_nvr_dlq                                      96.6
# percent_bc_gt_75                                    60.0
# pub_rec_bankruptcies                                 0.0
# tax_liens                                            0.0
# tot_hi_cred_lim                                 439570.0
# total_bal_ex_mort                                95768.0
# total_bc_limit                                   20300.0
# total_il_high_credit_limit                       88097.0
# revol_bal_joint                                      NaN
# sec_app_fico_range_low                               NaN
# sec_app_fico_range_high                              NaN
# sec_app_earliest_cr_line                             NaN
# sec_app_inq_last_6mths                               NaN
# sec_app_mort_acc                                     NaN
# sec_app_open_acc                                     NaN
# sec_app_revol_util                                   NaN
# sec_app_open_act_il                                  NaN
# sec_app_num_rev_accts                                NaN
# sec_app_chargeoff_within_12_mths                     NaN
# sec_app_collections_12_mths_ex_med                   NaN
# sec_app_mths_since_last_major_derog                  NaN
# disbursement_method                                 Cash

# %% [markdown]
# ## Обработаем строки

# %% [markdown]
# ### Обработаем статус займа.

# %% [markdown]
# Нас интересуют завершенные займы, поэтому удалим займы в следующих статусах:
#
# - Default
# - Current
# - Late (31-120 days)
# - Late (16-30 days)
# - In Grace Period
#
# Также уберем записи со статусами:
#
# - Does not meet the credit policy. Status:Fully Paid
# - Does not meet the credit policy. Status:Charged Off
#
# Эти кредиты были одобрены ранее, но не проходят для существующей кредитной политики, и скорее всего будут иметь другое распределение, что будет иметь негативный эффект на результаты нашего исследования.

# %%
loan_stat_delete = ['Default',
                    'Does not meet the credit policy. Status:Charged Off',
                    'Does not meet the credit policy. Status:Fully Paid',
                    'In Grace Period',
                    'Late (16-30 days)',
                    'Late (31-120 days)',
                    'Current']

accepted = accepted[~accepted['loan_status'].isin(loan_stat_delete)]
accepted['loan_status'].value_counts(dropna=False)
# Out:
# loan_status
# Fully Paid     1076751
# Charged Off     268559
# NaN                 33
# Name: count, dtype: int64

# %% [markdown]
# ### Обработаем тип заявки

# %% [markdown]
# Будем брать только индивидуальные заявки.

# %%
accepted = accepted[accepted['application_type'] == 'Individual']
accepted['application_type'].unique()
# Out:
# array(['Individual'], dtype=object)

# %% [markdown]
# Удалим сопутствующие колонки

# %%
sec_app_cols = ["application_type",
                "annual_inc_joint",
                "dti_joint",
                "verification_status_joint",
                "revol_bal_joint",
                "sec_app_fico_range_low",
                "sec_app_fico_range_high",
                "sec_app_earliest_cr_line",
                "sec_app_inq_last_6mths",
                "sec_app_mort_acc",
                "sec_app_open_acc",
                "sec_app_revol_util",
                "sec_app_open_act_il",
                "sec_app_num_rev_accts",
                "sec_app_chargeoff_within_12_mths",
                "sec_app_collections_12_mths_ex_med",
                "sec_app_mths_since_last_major_derog"]

accepted.drop(columns=sec_app_cols, inplace=True)

# %% [markdown]
# ### Посмотрим на пропуски

# %% [markdown]
# В нашем случае существуют 2 типа пропусков:
# - Пропуски, которые были проставленны намеренно, например, в колонке `mths_since_last_delinq` пропуск означает, что кредитуемый не допускал нарушений в принципе.
# - Пропуски, которые были допущенны в силу неполноты данных.

# %%
nan_content = dict()

for i, col in enumerate(accepted.columns):
    vals = [accepted[col].isna().sum(), len(accepted[col])]
    labels = ['nan', 'Not nan']
    if vals[0]/vals[1] != 0:
        nan_content[col] = vals[0]/vals[1]

# %%
nan_order = dict(sorted(nan_content.items(), key=lambda item: item[1]))

labels = list(nan_order.keys())
vals = list(nan_order.values())


nan_order
# Out:
# {'inq_last_6mths': 7.578570833112292e-07,
#  'tax_liens': 2.9556426249137938e-05,
#  'last_credit_pull_d': 4.0924282498806374e-05,
#  'collections_12_mths_ex_med': 4.2439996665428835e-05,
#  'chargeoff_within_12_mths': 4.2439996665428835e-05,
#  'pub_rec_bankruptcies': 0.0005282263870679268,
#  'last_pymnt_d': 0.001660464869534903,
#  'acc_open_past_24mths': 0.035832240756038226,
#  'mort_acc': 0.035832240756038226,
#  'total_bal_ex_mort': 0.035832240756038226,
#  'total_bc_limit': 0.035832240756038226,
#  'num_bc_sats': 0.04231949738918235,
#  'num_sats': 0.04231949738918235,
#  'mths_since_recent_bc': 0.045193291449098526,
#  'bc_open_to_buy': 0.045876120681161946,
#  'percent_bc_gt_75': 0.04618835779948617,
#  'bc_util': 0.0464467870648953,
#  'tot_coll_amt': 0.051175815264757375,
#  'tot_cur_bal': 0.051175815264757375,
#  'total_rev_hi_lim': 0.051175815264757375,
#  'mo_sin_rcnt_tl': 0.051175815264757375,
#  'num_accts_ever_120_pd': 0.051175815264757375,
#  'num_actv_bc_tl': 0.051175815264757375,
#  'num_actv_rev_tl': 0.051175815264757375,
#  'num_bc_tl': 0.051175815264757375,
#  'num_il_tl': 0.051175815264757375,
#  'num_op_rev_tl': 0.051175815264757375,
#  'num_rev_tl_bal_gt_0': 0.051175815264757375,
#  'num_tl_30dpd': 0.051175815264757375,
#  'num_tl_90g_dpd_24m': 0.051175815264757375,
#  'num_tl_op_past_12m': 0.051175815264757375,
#  'tot_hi_cred_lim': 0.051175815264757375,
#  'total_il_high_credit_limit': 0.051175815264757375,
#  'mo_sin_old_rev_tl_op': 0.051176573121840686,
#  'mo_sin_rcnt_rev_tl_op': 0.051176573121840686,
#  'num_rev_accts': 0.051176573121840686,
#  'avg_cur_bal': 0.051190214549340286,
#  'pct_tl_nvr_dlq': 0.0512925252555873,
#  'emp_length': 0.056660426976680736,
#  'mo_sin_old_il_acct': 0.07943403233018317,
#  'num_tl_120dpd_2m': 0.0889724215807383,
#  'mths_since_recent_inq': 0.13004221263954044,
#  'mths_since_last_delinq': 0.5042144432402937,
#  'open_act_il': 0.6119218497775689,
#  'open_il_12m': 0.6119218497775689,
#  'open_il_24m': 0.6119218497775689,
#  'total_bal_il': 0.6119218497775689,
#  'open_rv_12m': 0.6119218497775689,
#  'open_rv_24m': 0.6119218497775689,
#  'max_bal_bc': 0.6119218497775689,
#  'inq_fi': 0.6119218497775689,
#  'open_acc_6m': 0.6119226076346522,
#  'total_cu_tl': 0.6119226076346522,
#  'inq_last_12m': 0.6119226076346522,
#  'all_util': 0.6119521640609014,
#  'mths_since_rcnt_il': 0.6221226061189381,
#  'il_util': 0.6637532114193905,
#  'mths_since_recent_revol_delinq': 0.6651272063114337,
#  'mths_since_last_major_derog': 0.7365628149843503,
#  'mths_since_recent_bc_dlq': 0.7624337822373457,
#  'mths_since_last_record': 0.8303074626186994,
#  'next_pymnt_d': 1.0}

# %% [markdown]
# ### Удалим пропуски в колонках

# %% [markdown]
# Будем удалять записи в колонках, в которых пропусков не более 15%.
# В таком случае целостность данных не пострадает.

# %%
just_drop_cols = ['inq_last_6mths',
                  'tax_liens',
                  'last_credit_pull_d',
                  'collections_12_mths_ex_med',
                  'chargeoff_within_12_mths',
                  'pub_rec_bankruptcies',
                  'acc_open_past_24mths',
                  'mort_acc',
                  'total_bal_ex_mort',
                  'total_bc_limit',
                  'num_bc_sats',
                  'num_sats',
                  'mths_since_recent_bc',
                  'bc_open_to_buy',
                  'percent_bc_gt_75',
                  'bc_util',
                  'tot_coll_amt',
                  'tot_cur_bal',
                  'total_rev_hi_lim',
                  'mo_sin_rcnt_tl',
                  'num_accts_ever_120_pd',
                  'num_actv_bc_tl',
                  'num_actv_rev_tl',
                  'num_bc_tl',
                  'num_il_tl',
                  'num_op_rev_tl',
                  'num_rev_tl_bal_gt_0',
                  'num_tl_30dpd',
                  'num_tl_90g_dpd_24m',
                  'num_tl_op_past_12m',
                  'tot_hi_cred_lim',
                  'total_il_high_credit_limit',
                  'mo_sin_old_rev_tl_op',
                  'mo_sin_rcnt_rev_tl_op',
                  'num_rev_accts',
                  'avg_cur_bal',
                  'pct_tl_nvr_dlq',
                  'emp_length',
                  'mo_sin_old_il_acct',
                  'num_tl_120dpd_2m',
                  'mths_since_recent_inq',
                  'last_pymnt_d']

accepted.dropna(subset=just_drop_cols, inplace=True)

# %% [markdown]
# Для переменных формата `mths_since_***` отсутствие значения показывает, что события не произошло.
# Поэтому для таких переменных мы будем заводить еще одну колонку-флаг, произошло ли событие вообще, а значения заполнять очень большим числом

# %%
time_since = [
    'mths_since_last_delinq',
    'mths_since_recent_revol_delinq',
    'mths_since_last_major_derog',
    'mths_since_recent_bc_dlq',
    'mths_since_last_record',
]

for col_name in time_since:
    max_val = accepted[col_name].max()
    fill_val = max_val**2 + 1000  # Fill with unrealistic value

    new_col_name = f'has_been_{col_name.lstrip("mths_since_")}'

    accepted[new_col_name] = accepted[col_name].isna().astype('int')
    accepted[col_name].fillna(fill_val, inplace=True)

# %% [markdown]
# Заметим, что для части колонок отсутствуют целые блоки данных. Удалим колонки, в которых пропусков больше 50%. Данных без них все еще достаточно, чтобы сделать выводы.

# %%
missing_cols = [i for i in nan_order if nan_order[i] >= 0.5]


accepted.drop(columns=missing_cols, inplace=True)

# %% [markdown]
# ### Обработаем время жизни клиента

# %%
accepted['term'].value_counts(dropna=False)
# Out:
# term
#  36 months    734805
#  60 months    248293
# Name: count, dtype: int64

# %% [markdown]
# В колонке `term` ровно 2 значения: 36 или 60 месяцев, поэтому просто отобразим значения в числа.

# %%
accepted['term'] = accepted['term'].map({' 36 months': 36, ' 60 months': 60})

# %% [markdown]
# ### Выделим целевую переменную

# %% [markdown]
# В рамках задачи, целевая переменная состоит из двух колонок: `duration` и `event`.
# Первая отвечает за время наблюдения за клиентом, вторая показывает, произошло ли событие(дефолт по кредиту) за время наблюдений.

# %%
def extract_target(row):
    if row['loan_status'] != 'Fully Paid':
        return int((row['last_pymnt_d'] - row['issue_d']).components.days/30)

    return row['term']


accepted['duration'] = accepted.apply(extract_target, axis=1)
accepted['event'] = (accepted['loan_status'] != 'Fully Paid')
accepted.drop(columns=['last_pymnt_d', 'loan_status', 'term'], inplace=True)
accepted[['duration', 'event']].head(15)
# Out:
#     duration  event
# 0         36  False
# 1         36  False
# 4         60  False
# 6         36  False
# 7         36  False
# 8         36  False
# 9         36  False
# 12        36  False
# 13        17   True
# 15        36  False
# 16        36  False
# 17        60  False
# 20        60  False
# 21        60  False
# 22        36  False

# %% [markdown]
# ### Подготовка категорий

# %% [markdown]
# В данных встречаются колонки `emp_length` и `sub_grade`.
# Эти колонки являются категориальными, но при этом содержат в себе порядок.
# Будем кодировать эти колонки вручную, согласно внутреннему порядку.

# %%
mapping_dict = {
                "emp_length": {
                    "10+ years": 10,
                    "9 years": 9,
                    "8 years": 8,
                    "7 years": 7,
                    "6 years": 6,
                    "5 years": 5,
                    "4 years": 4,
                    "3 years": 3,
                    "2 years": 2,
                    "1 year": 1,
                    "< 1 year": 0,
                    "n/a": 0
                },
                "sub_grade":
                    dict([(val, i+1) for i, val in enumerate(sorted(accepted['sub_grade'].unique()))])
                }

accepted = accepted.replace(mapping_dict)
accepted[['emp_length', 'sub_grade']].head()
# Out:
#    emp_length  sub_grade
# 0          10         14
# 1          10         11
# 4           3         26
# 6          10          7
# 7          10          6

# %% [markdown]
# ### Удалим колонки с единственным значением.

# %% [markdown]
# После всех действий у нас остались "мусорные колонки", содержащие одно значение. Удалим их.

# %%
accepted = accepted.loc[:,accepted.apply(pd.Series.nunique) != 1]

# %% [markdown]
# ## Выгрузка данных

# %%
accepted.isna().sum()
# Out:
# loan_amnt                       0
# installment                     0
# sub_grade                       0
# emp_length                      0
# home_ownership                  0
# annual_inc                      0
# verification_status             0
# issue_d                         0
# purpose                         0
# addr_state                      0
# dti                             0
# delinq_2yrs                     0
# earliest_cr_line                0
# fico_range_low                  0
# fico_range_high                 0
# inq_last_6mths                  0
# open_acc                        0
# pub_rec                         0
# total_acc                       0
# initial_list_status             0
# last_credit_pull_d              0
# collections_12_mths_ex_med      0
# acc_now_delinq                  0
# tot_coll_amt                    0
# tot_cur_bal                     0
# total_rev_hi_lim                0
# acc_open_past_24mths            0
# avg_cur_bal                     0
# bc_open_to_buy                  0
# bc_util                         0
# chargeoff_within_12_mths        0
# delinq_amnt                     0
# mo_sin_old_il_acct              0
# mo_sin_old_rev_tl_op            0
# mo_sin_rcnt_rev_tl_op           0
# mo_sin_rcnt_tl                  0
# mort_acc                        0
# mths_since_recent_bc            0
# mths_since_recent_inq           0
# num_accts_ever_120_pd           0
# num_actv_bc_tl                  0
# num_actv_rev_tl                 0
# num_bc_sats                     0
# num_bc_tl                       0
# num_il_tl                       0
# num_op_rev_tl                   0
# num_rev_accts                   0
# num_rev_tl_bal_gt_0             0
# num_sats                        0
# num_tl_120dpd_2m                0
# num_tl_30dpd                    0
# num_tl_90g_dpd_24m              0
# num_tl_op_past_12m              0
# pct_tl_nvr_dlq                  0
# percent_bc_gt_75                0
# pub_rec_bankruptcies            0
# tax_liens                       0
# tot_hi_cred_lim                 0
# total_bal_ex_mort               0
# total_bc_limit                  0
# total_il_high_credit_limit      0
# disbursement_method             0
# has_been_last_delinq            0
# has_been_recent_revol_delinq    0
# has_been_last_major_derog       0
# has_been_recent_bc_dlq          0
# has_been_last_record            0
# duration                        0
# event                           0
# dtype: int64

# %%
accepted.shape
# Out:
# (983098, 69)

# %%
accepted.head().transpose()
# Out:
#                                                 0                    1
# loan_amnt                                  3600.0              24700.0  \
# installment                                123.03               820.28
# sub_grade                                      14                   11
# emp_length                                     10                   10
# home_ownership                           MORTGAGE             MORTGAGE
# annual_inc                                55000.0              65000.0
# verification_status                  Not Verified         Not Verified
# issue_d                       2015-12-01 00:00:00  2015-12-01 00:00:00
# purpose                        debt_consolidation       small_business
# addr_state                                     PA                   SD
# dti                                          5.91                16.06
# delinq_2yrs                                   0.0                  1.0
# earliest_cr_line              2003-08-01 00:00:00  1999-12-01 00:00:00
# fico_range_low                              675.0                715.0
# fico_range_high                             679.0                719.0
# inq_last_6mths                                1.0                  4.0
# open_acc                                      7.0                 22.0
# pub_rec                                       0.0                  0.0
# total_acc                                    13.0                 38.0
# initial_list_status                             w                    w
# last_credit_pull_d            2019-03-01 00:00:00  2019-03-01 00:00:00
# collections_12_mths_ex_med                    0.0                  0.0
# acc_now_delinq                                0.0                  0.0
# tot_coll_amt                                722.0                  0.0
# tot_cur_bal                              144904.0             204396.0
# total_rev_hi_lim                           9300.0             111800.0
# acc_open_past_24mths                          4.0                  4.0
# avg_cur_bal                               20701.0               9733.0
# bc_open_to_buy                             1506.0              57830.0
# bc_util                                      37.2                 27.1
# chargeoff_within_12_mths                      0.0                  0.0
# delinq_amnt                                   0.0                  0.0
# mo_sin_old_il_acct                          148.0                113.0
# mo_sin_old_rev_tl_op                        128.0                192.0
# mo_sin_rcnt_rev_tl_op                         3.0                  2.0
# mo_sin_rcnt_tl                                3.0                  2.0
# mort_acc                                      1.0                  4.0
# mths_since_recent_bc                          4.0                  2.0
# mths_since_recent_inq                         4.0                  0.0
# num_accts_ever_120_pd                         2.0                  0.0
# num_actv_bc_tl                                2.0                  5.0
# num_actv_rev_tl                               4.0                  5.0
# num_bc_sats                                   2.0                 13.0
# num_bc_tl                                     5.0                 17.0
# num_il_tl                                     3.0                  6.0
# num_op_rev_tl                                 4.0                 20.0
# num_rev_accts                                 9.0                 27.0
# num_rev_tl_bal_gt_0                           4.0                  5.0
# num_sats                                      7.0                 22.0
# num_tl_120dpd_2m                              0.0                  0.0
# num_tl_30dpd                                  0.0                  0.0
# num_tl_90g_dpd_24m                            0.0                  0.0
# num_tl_op_past_12m                            3.0                  2.0
# pct_tl_nvr_dlq                               76.9                 97.4
# percent_bc_gt_75                              0.0                  7.7
# pub_rec_bankruptcies                          0.0                  0.0
# tax_liens                                     0.0                  0.0
# tot_hi_cred_lim                          178050.0             314017.0
# total_bal_ex_mort                          7746.0              39475.0
# total_bc_limit                             2400.0              79300.0
# total_il_high_credit_limit                13734.0              24667.0
# disbursement_method                          Cash                 Cash
# has_been_last_delinq                            0                    0
# has_been_recent_revol_delinq                    0                    0
# has_been_last_major_derog                       0                    1
# has_been_recent_bc_dlq                          0                    1
# has_been_last_record                            1                    1
# duration                                       36                   36
# event                                       False                False
#
#                                                 4                    6
# loan_amnt                                 10400.0              20000.0  \
# installment                                289.91               637.58
# sub_grade                                      26                    7
# emp_length                                      3                   10
# home_ownership                           MORTGAGE             MORTGAGE
# annual_inc                               104433.0             180000.0
# verification_status               Source Verified         Not Verified
# issue_d                       2015-12-01 00:00:00  2015-12-01 00:00:00
# purpose                            major_purchase   debt_consolidation
# addr_state                                     PA                   MN
# dti                                         25.37                14.67
# delinq_2yrs                                   1.0                  0.0
# earliest_cr_line              1998-06-01 00:00:00  1990-06-01 00:00:00
# fico_range_low                              695.0                680.0
# fico_range_high                             699.0                684.0
# inq_last_6mths                                3.0                  0.0
# open_acc                                     12.0                 12.0
# pub_rec                                       0.0                  0.0
# total_acc                                    35.0                 27.0
# initial_list_status                             w                    f
# last_credit_pull_d            2018-03-01 00:00:00  2019-03-01 00:00:00
# collections_12_mths_ex_med                    0.0                  0.0
# acc_now_delinq                                0.0                  0.0
# tot_coll_amt                                  0.0                  0.0
# tot_cur_bal                              331730.0             360358.0
# total_rev_hi_lim                          34000.0              94200.0
# acc_open_past_24mths                         10.0                  6.0
# avg_cur_bal                               27644.0              30030.0
# bc_open_to_buy                             4567.0                  0.0
# bc_util                                      77.5                102.9
# chargeoff_within_12_mths                      0.0                  0.0
# delinq_amnt                                   0.0                  0.0
# mo_sin_old_il_acct                          128.0                142.0
# mo_sin_old_rev_tl_op                        210.0                306.0
# mo_sin_rcnt_rev_tl_op                         4.0                 10.0
# mo_sin_rcnt_tl                                4.0                 10.0
# mort_acc                                      6.0                  4.0
# mths_since_recent_bc                          4.0                 12.0
# mths_since_recent_inq                         1.0                 10.0
# num_accts_ever_120_pd                         0.0                  0.0
# num_actv_bc_tl                                4.0                  4.0
# num_actv_rev_tl                               6.0                  6.0
# num_bc_sats                                   5.0                  4.0
# num_bc_tl                                     9.0                  5.0
# num_il_tl                                    10.0                  7.0
# num_op_rev_tl                                 7.0                  9.0
# num_rev_accts                                19.0                 16.0
# num_rev_tl_bal_gt_0                           6.0                  6.0
# num_sats                                     12.0                 12.0
# num_tl_120dpd_2m                              0.0                  0.0
# num_tl_30dpd                                  0.0                  0.0
# num_tl_90g_dpd_24m                            0.0                  0.0
# num_tl_op_past_12m                            4.0                  2.0
# pct_tl_nvr_dlq                               96.6                 96.3
# percent_bc_gt_75                             60.0                100.0
# pub_rec_bankruptcies                          0.0                  0.0
# tax_liens                                     0.0                  0.0
# tot_hi_cred_lim                          439570.0             388852.0
# total_bal_ex_mort                         95768.0             116762.0
# total_bc_limit                            20300.0              31500.0
# total_il_high_credit_limit                88097.0              46452.0
# disbursement_method                          Cash                 Cash
# has_been_last_delinq                            0                    0
# has_been_recent_revol_delinq                    0                    1
# has_been_last_major_derog                       1                    1
# has_been_recent_bc_dlq                          0                    1
# has_been_last_record                            1                    1
# duration                                       60                   36
# event                                       False                False
#
#                                                 7
# loan_amnt                                 20000.0
# installment                                631.26
# sub_grade                                       6
# emp_length                                     10
# home_ownership                           MORTGAGE
# annual_inc                                85000.0
# verification_status                  Not Verified
# issue_d                       2015-12-01 00:00:00
# purpose                            major_purchase
# addr_state                                     SC
# dti                                         17.61
# delinq_2yrs                                   1.0
# earliest_cr_line              1999-02-01 00:00:00
# fico_range_low                              705.0
# fico_range_high                             709.0
# inq_last_6mths                                0.0
# open_acc                                      8.0
# pub_rec                                       0.0
# total_acc                                    15.0
# initial_list_status                             w
# last_credit_pull_d            2019-03-01 00:00:00
# collections_12_mths_ex_med                    0.0
# acc_now_delinq                                0.0
# tot_coll_amt                                  0.0
# tot_cur_bal                              141601.0
# total_rev_hi_lim                          14500.0
# acc_open_past_24mths                          4.0
# avg_cur_bal                               17700.0
# bc_open_to_buy                            13674.0
# bc_util                                       5.7
# chargeoff_within_12_mths                      0.0
# delinq_amnt                                   0.0
# mo_sin_old_il_acct                          149.0
# mo_sin_old_rev_tl_op                         55.0
# mo_sin_rcnt_rev_tl_op                        32.0
# mo_sin_rcnt_tl                               13.0
# mort_acc                                      3.0
# mths_since_recent_bc                         32.0
# mths_since_recent_inq                         8.0
# num_accts_ever_120_pd                         1.0
# num_actv_bc_tl                                2.0
# num_actv_rev_tl                               2.0
# num_bc_sats                                   3.0
# num_bc_tl                                     3.0
# num_il_tl                                     9.0
# num_op_rev_tl                                 3.0
# num_rev_accts                                 3.0
# num_rev_tl_bal_gt_0                           2.0
# num_sats                                      8.0
# num_tl_120dpd_2m                              0.0
# num_tl_30dpd                                  0.0
# num_tl_90g_dpd_24m                            1.0
# num_tl_op_past_12m                            0.0
# pct_tl_nvr_dlq                               93.3
# percent_bc_gt_75                              0.0
# pub_rec_bankruptcies                          0.0
# tax_liens                                     0.0
# tot_hi_cred_lim                          193390.0
# total_bal_ex_mort                         27937.0
# total_bc_limit                            14500.0
# total_il_high_credit_limit                36144.0
# disbursement_method                          Cash
# has_been_last_delinq                            0
# has_been_recent_revol_delinq                    1
# has_been_last_major_derog                       0
# has_been_recent_bc_dlq                          1
# has_been_last_record                            1
# duration                                       36
# event                                       False

# %%
accepted.to_csv('lending_data/accepted_clean.csv', index=False)

# %% [markdown]
# Colab only

# %%
# !cp ./lending_data/accepted_clean.csv /gdrive/Othercomputers/"My Zenbook"/xgbse_analytics/lending_data/accepted_clean.csv
